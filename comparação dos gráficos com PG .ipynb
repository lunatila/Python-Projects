# %%
import numpy as np
import math 
import matplotlib.pyplot as plt
from numpy import log as ln
import scipy.special as sc


def f(x): return 0.5*ln(4*x/(math.exp(0.57722)))
x = [1.05**(n-1) for n in range(1, 1000+1)]
y = [f(n) for n in x]
yb = [-0.5*sc.expi((-1/(4*n))) for n in x]
fig = plt.figure(figsize=(8,6))
plt.scatter(x,yb)
plt.plot(x,yb)
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("td", fontsize=20)
plt.ylabel("f(td)", fontsize=20)
plt.title("Comparação do curva Solucão da Linha-Fonte x Aproximação da Solução da linha-Fonte", fontsize=25)
plt.show()

# %%
def f(x): return 0.5*ln(4*x/(math.exp(0.57722)*(10**2)))
x = [1.2**(n-1) for n in range(1, 1000+1)]
y = [f(n) for n in x]
yb = [-0.5*sc.expi((-100/(4*n))) for n in x]
fig = plt.figure(figsize=(8,6))
plt.scatter(x,yb)
plt.plot(x,yb)
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("td", fontsize=20)
plt.ylabel("f(td)", fontsize=20)
plt.title("Comparação do curva Solucão da Linha-Fonte x Aproximação da Solução da linha-Fonte", fontsize=25)
plt.show()

# %%
def f(x): return 0.5*ln(4*100/(math.exp(0.57722)*(x**2)))
x = [1*1.2**(n-1) for n in range(1, 1000+1)]
y = [f(n) for n in x]
yb = [-0.5*sc.expi((-(n**2)/(400))) for n in x]
fig = plt.figure(figsize=(8,6))
plt.scatter(x,yb)
plt.plot(x,yb)
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("rd", fontsize=20)
plt.ylabel("f(rd)", fontsize=20)
plt.title("Comparação do curva Solucão da Linha-Fonte x Aproximação da Solução da linha-Fonte", fontsize=25)
plt.show()

# %%
def f(x): return 0.5*ln(4*1000/(math.exp(0.57722)*x**2))
x = [1*1.2**(n-1) for n in range(1, 1000+1)]
y = [f(n) for n in x]
yb = [-0.5*(sc.expi(-(n**2)/4000)) for n in x]
fig = plt.figure(figsize=(8,6))
plt.scatter(x,yb)
plt.plot(x,yb)
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("rd", fontsize=20)
plt.ylabel("f(rd)", fontsize=20)
plt.title("Comparação do curva Solucão da Linha-Fonte x Aproximação da Solução da linha-Fonte", fontsize=25)
plt.show()
