# %%
import numpy as np
import math 
import matplotlib.pyplot as plt
from numpy import log as ln


def f(x): return 0.5*ln(4*x/(math.exp(0.57722)))
x = [1.05**(n-1) for n in range(1, 1000+1)]
y = [f(n) for n in x]

# %%
fig = plt.figure(figsize=(8,6))
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("td", fontsize=20)
plt.ylabel("f(td)", fontsize=20)
plt.title("Aproximação da Solução da linha-Fonte", fontsize=25)
plt.show()

# %%
import numpy as np
import math 
import matplotlib.pyplot as plt
from numpy import log as ln


def f(x): return 0.5*ln(4*x/(math.exp(0.57722)*(10**2)))
x = [1.05**(n-1) for n in range(1, 1000+1)]
y = [f(n) for n in x]
fig = plt.figure(figsize=(8,6))
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("td", fontsize=20)
plt.ylabel("f(td)", fontsize=20)
plt.title("Aproximação da Solução da linha Fonte", fontsize=25)
plt.show()

# %%
import numpy as np
import math 
import matplotlib.pyplot as plt
from numpy import log as ln


def f(x): return 0.5*ln(4*100/(math.exp(0.57722)*(x**2)))
x = [1.05**(n-1) for n in range(1, 1000+1)]
y = [f(n) for n in x]
fig = plt.figure(figsize=(8,6))
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("rd", fontsize=20)
plt.ylabel("f(rd)", fontsize=20)
plt.title("Aproximação da Solução da linha Fonte", fontsize=25)
plt.show()

# %%
import numpy as np
import math 
import matplotlib.pyplot as plt
from numpy import log as ln


def f(x): return 0.5*ln(4*1000/(math.exp(0.57722)*x**2))
x = [1.05**(n-1) for n in range(1, 1000+1)]
y = [f(n) for n in x]
fig = plt.figure(figsize=(8,6))
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("rd", fontsize=20)
plt.ylabel("f(rd)", fontsize=20)
plt.title("Aproximação da Solução da linha Fonte", fontsize=25)
plt.show()

# %%
import scipy.special as sc
x = [1.05**(n-1) for n in range(1, 1000+1)]
y = [-0.5*sc.expi((-1/(4*n))) for n in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("rd", fontsize=20)
plt.ylabel("f(rd)", fontsize=20)
plt.title("Solução da linha Fonte", fontsize=25)
plt.show()

# %%
import scipy.special as sc
y = [-0.5*sc.expi((-100/(4*n))) for n in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("rd", fontsize=20)
plt.ylabel("f(rd)", fontsize=20)
plt.title("Solução da linha Fonte", fontsize=25)
plt.show()

# %%
y = [-0.5*sc.expi((-(n**2)/(400))) for n in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("td", fontsize=20)
plt.ylabel("f(td)", fontsize=20)
plt.title("Solução da linha Fonte", fontsize=25)
plt.show()

# %%
y = [-0.5*sc.expi((-(n**2)/(4000))) for n in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("td", fontsize=20)
plt.ylabel("f(t.d)", fontsize=20)
plt.title("Solução da linha Fonte", fontsize=25)
plt.show()
